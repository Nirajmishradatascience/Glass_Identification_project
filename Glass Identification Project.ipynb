# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
glass = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv")
names = ['Id','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','type_of_glass']
glass.columns = names

# %%
glass
# Out:
#       Id       RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  \
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...   ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00
#
#      type_of_glass
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# ...

# %%
glass.plot()
# Out:
# <Axes: >

# %%
glass.plot(kind ='hist',x='Na',y='type_of_glass')
plt.show()

# %%
glass.plot(kind ='scatter',x='RI',y='type_of_glass')
plt.show()

# %%
features = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']
label = ['type_of_glass']

X = glass[features]

y = glass[label]

# %%
x2 = X.values

from matplotlib import pyplot as plt
import seaborn as sns
for i in range(1,9):
        sns.distplot(x2[i])
        plt.xlabel(features[i])
        plt.show()
# Out:
# <ipython-input-14-58eb0bc1aaa1>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x2[i])
# <ipython-input-14-58eb0bc1aaa1>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x2[i])
# <ipython-input-14-58eb0bc1aaa1>:6: UserWarning:
#
# ...

# %%
import seaborn as sns
x2 = pd.DataFrame(X)

plt.figure(figsize=(8,8))
sns.pairplot(data=x2)
plt.show()

# %%
coreleation= X.corr()
plt.figure(figsize=(15,15))
sns.heatmap(coreleation,cbar=True,square=True,annot=True,fmt='.1f',annot_kws={'size': 15},xticklabels=features,yticklabels=features,alpha=0.7,cmap= 'coolwarm')
plt.show()

# %%
sns.pairplot(glass)

# %%
sns.violinplot(x='RI', y='type_of_glass', data=glass)
# Out:
# <Axes: xlabel='RI', ylabel='type_of_glass'>

# %%
glass['Si'] = [1 if x >= 6 else 0 for x in glass['Na']]
X = glass.drop(['Na','Si'], axis = 1)
Y = glass['Si']

# %%
glass['Si'].value_counts()
# Out:
# 1    213
# Name: Si, dtype: int64

# %%
X
# Out:
#       Id  RI    Mg    Al     K    Ca    Ba    Fe  type_of_glass
# 0      2   1  3.60  1.36  0.48  7.83  0.00  0.00              1
# 1      3   1  3.55  1.54  0.39  7.78  0.00  0.00              1
# 2      4   1  3.69  1.29  0.57  8.22  0.00  0.00              1
# 3      5   1  3.62  1.24  0.55  8.07  0.00  0.00              1
# 4      6   1  3.61  1.62  0.64  8.07  0.00  0.26              1
# ..   ...  ..   ...   ...   ...   ...   ...   ...            ...
# 208  210   1  0.00  2.88  0.08  9.18  1.06  0.00              1
# 209  211   1  0.00  1.99  0.00  8.40  1.59  0.00              1
# 210  212   1  0.00  2.02  0.00  8.44  1.64  0.00              1
# 211  213   1  0.00  1.94  0.00  8.48  1.57  0.00              1
# 212  214   1  0.00  2.08  0.00  8.62  1.67  0.00              1
#
# [213 rows x 9 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# ...

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    1
# 209    1
# 210    1
# 211    1
# 212    1
# Name: Si, Length: 213, dtype: int64

# %%
glass.plot(kind='box', subplots=True)
plt.figure(figsize=(100,100))
plt.figure()
